# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set()

# %%
in_array = np.linspace(-5, 5, 100) 
out_array = np.tanh(in_array) 

bins = np.linspace(-1, 1, 10)

# %%
plt.plot(in_array, out_array, label="Activation function") 
plt.title("Uniform Binning") 
plt.xlabel("") 
plt.ylabel("") 
for y in bins[:-1]:
    plt.hlines(y, -5, 5, linewidth=1, linestyles="dotted")
plt.hlines(bins[-1], -5, 5, linewidth=1, linestyles="dotted", label="Bin Borders")
plt.legend(loc="lower right")
plt.tight_layout()
#plt.show()
plt.savefig("uniform_bins.png", dpi=700)

# %%
import pickle
with open("mains/bins.pickle", 'rb') as f:
    bins_ars = pickle.load(f)
    f.close()
    
adapt_bins = bins_ars[-3000][-2]

# %%
plt.plot(in_array, out_array, label="Activation function") 
plt.title("Adaptive Binning") 
plt.xlabel("") 
plt.ylabel("") 

for y in adapt_bins[:-1]:
    plt.hlines(y, -5, 5, linewidth=1, linestyles="dotted")
plt.hlines(adapt_bins[-1], -5, 5, linewidth=1, linestyles="dotted", label="Bin Borders")
plt.legend(loc="lower right")
plt.tight_layout()
#plt.show() 
plt.savefig("adaptive_bins.png", dpi=700)

# %%
import pickle

# %%
with open("mains/bins.pickle", 'rb') as f:
    bins_ars = pickle.load(f)
    f.close()

# %%
# !pwd
# Out:
# /home/quantzz/ibbsc

# %%
# !ls ./data/max_val_folder/
# Out:
# max_values0_256.pickle			MI_XH_MI_YH_run_9_256_2adaptive.pickle
# max_values9_256.pickle			training_history_run_0_256.pickle
# MI_XH_MI_YH_run_0_256_2adaptive.pickle	training_history_run_9_256.pickle

# %%
with open("data/max_val_folder/max_values9_256.pickle", 'rb') as f:
    max_vals = pickle.load(f)
    f.close()

# %%
max_vals = np.array(max_vals)

# %%
max_vals.shape
# Out:
# (8000, 6)

# %%
max_vals.T.shape
# Out:
# (6, 8000)

# %%
max_vals.T
# Out:
# array([[2.1734831e+00, 2.1821594e+00, 2.1877692e+00, ..., 3.8297527e+00,
#         3.8281229e+00, 3.8276064e+00],
#        [9.2340088e-01, 9.3242300e-01, 9.4850981e-01, ..., 2.3939359e+00,
#         2.3954847e+00, 2.3964887e+00],
#        [6.9471353e-01, 6.9205153e-01, 7.0355266e-01, ..., 1.9998117e+01,
#         2.0022518e+01, 2.0019960e+01],
#        [3.8402238e-01, 4.1256106e-01, 4.4348517e-01, ..., 4.6208214e+01,
#         4.6296612e+01, 4.6298218e+01],
#        [7.4386790e-02, 7.9350784e-02, 8.5550360e-02, ..., 9.0027817e+01,
#         9.0188248e+01, 9.0208778e+01],
#        [5.2065879e-01, 5.2550519e-01, 5.2971190e-01, ..., 1.0000000e+00,
#         1.0000000e+00, 1.0000000e+00]], dtype=float32)

# %%
#source https://stackoverflow.com/questions/4700614/how-to-put-the-legend-out-of-the-plot
fig = plt.figure()
ax = plt.subplot(111)
for idx, i in enumerate(max_vals.T[:-1]):
    ax.plot(i, label = "ReLU layer {}".format(idx+1))
ax.set_xlabel("Epoch")
ax.set_ylabel("Activation value")

ax.legend(loc="best",fancybox=True, shadow=True)

# %%
fig.savefig("act_layers.png")
